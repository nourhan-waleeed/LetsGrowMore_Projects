# %% [markdown]
# #  Project Name: Music Recommendation System

# %% [markdown]
# ###   1.Introduction
# ###   2.Libraries
# ###   3.File Path
# ###   4.Preprocessing
# ###   5.EDA
# ###   6.Modeling

# %% [markdown]
# # 1) Introduction

# %% [markdown]
# **THE AIM OF THE PROJECT:**
#
# Is to predict the chances of a user listening to a song repetitively after the first observable listening event within a time window was triggered. If there are recurring listening event(s) triggered within a month after the user’s very first observable listening event, its target is marked 1, and 0 otherwise

# %% [markdown]
# # 2) Library

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import numpy as np

from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt
import seaborn as sns

import warnings; 
warnings.filterwarnings("always")
warnings.filterwarnings("ignore")

# %% [markdown]
# # 3) File Path

# %%
train = pd.read_csv('train.csv', nrows = 100000)
songs = pd.read_csv('songs.csv')
members = pd.read_csv('members.csv')
song_extra_info = pd.read_csv('song_extra_info.csv')
test = pd.read_csv('test.csv')

#sample_submission = pd.read_csv('sample_submission.csv')
#merging 
train_s = pd.merge(train, songs,on='song_id',how='left')
train_extra = pd.merge(train_s,song_extra_info, on='song_id', how= 'left')

merged_df = pd.merge(train_extra, members, on='msno', how='left')

del train,songs, members, song_extra_info, train_s,train_extra

# %% [markdown]
# # 4) Preprocessing

# %%
merged_df
# Out:
#                                                msno  \
# 0      FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1      Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2      Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3      Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4      FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# ...                                             ...
# 99995  EedNarOVNUU5ppYW/ho+KV8V29zuf7m3+Df5qnQ9FT4=
# 99996  xyxz9lf8ipoxELeDLlazmHVZHE1ZYqE6iwfJWkH3Ojc=
# 99997  vDi/nHqBu7wb+DtI2Ix4TupWQatUEFR41mDC0c8Voh8=
# 99998  xyxz9lf8ipoxELeDLlazmHVZHE1ZYqE6iwfJWkH3Ojc=
# 99999  n8TgRhOBw+DthR6N6ie/63yp3KHA20UVHlbK9nY9nIc=
#
#                                             song_id source_system_tab  \
# 0      BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1      bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2      JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3      2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4      3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# ...                                             ...               ...
# 99995  c7bvJHblBfQGFJG+DcltwclubmlYvIRTT964Lu4WWXI=        my library
# 99996  MZTwICqr12ijCeBaWeKVJZ67Bz7NI0WA4bqB1IwR4jI=        my library
# 99997  xK0clTH8TvjG6sKmJXZuMLzhikhlEsolLtx2AHBpmbQ=        my library
# 99998  SoPkcfpiBjDpZSNPN3HdbPI8WAkuenayPXyBRK91T2s=        my library
# 99999  PEEg0ODi9cPg1VXM9EOhZtV39sBJFr/9cIflhbHJ5Bs=        my library
#
#         source_screen_name      source_type  target  song_length genre_ids  \
# 0                  Explore  online-playlist       1     206471.0       359
# 1      Local playlist more   local-playlist       1     284584.0      1259
# 2      Local playlist more   local-playlist       1     225396.0      1259
# 3      Local playlist more   local-playlist       1     255512.0      1019
# 4                  Explore  online-playlist       1     187802.0      1011
# ...                    ...              ...     ...          ...       ...
# 99995  Local playlist more   local-playlist       1     236982.0       465
# 99996  Local playlist more    local-library       0     228241.0       465
# 99997  Local playlist more    local-library       1     196812.0       465
# 99998  Local playlist more    local-library       0     215775.0       465
# 99999  Local playlist more    local-library       1     191425.0       465
#
#              artist_name                                           composer  \
# 0               Bastille                               Dan Smith| Mark Crew
# 1        Various Artists                                                NaN
# 2                    Nas               N. Jones、W. Adams、J. Lordan、D. Ingle
# 3               Soundway                                      Kwadwo Donkoh
# 4            Brett Young            Brett Young| Kelly Archer| Justin Ebach
# ...                  ...                                                ...
# 99995               2NE1                                                NaN
# 99996      One Direction  Wayne Hector| John Ryan| Julian Bunetta| Ed Dr...
# 99997  Michael Giacchino       Mikkel Eriksen|Sia Furler|Tor Erik Hermansen
# 99998         Katy Perry  Katy Perry| Max Martin| Jordan Houston| Lukasz...
# 99999      孫盛希 (Shi Shi)                                                孫盛希
#
#                                                 lyricist  language  \
# 0                                                    NaN      52.0
# 1                                                    NaN      52.0
# 2                                                    NaN      52.0
# 3                                                    NaN      -1.0
# 4                                                    NaN      52.0
# ...                                                  ...       ...
# 99995                                                NaN      31.0
# 99996  Wayne Hector| John Ryan| Julian Bunetta| Ed Dr...      52.0
# 99997                                                NaN      52.0
# 99998                                                NaN      52.0
# 99999                                                孫盛希       3.0
#
#                                           name          isrc  city  bd  \
# 0                                   Good Grief  GBUM71602854     1   0
# 1                           Lords of Cardboard  US3C69910183    13  24
# 2      Hip Hop Is Dead(Album Version (Edited))  USUM70618761    13  24
# 3                                 Disco Africa  GBUQH1000063    13  24
# 4                            Sleep Without You  QM3E21606003     1   0
# ...                                        ...           ...   ...  ..
# 99995                               I Love You  TWA531200396    14   0
# 99996                            Steal My Girl  GBHMU1400159     1   0
# 99997                           Try Everything  USWD11575402    13   0
# 99998                               Dark Horse  USUM71311296     1   0
# 99999                                      你的誰  TWA451499001     1   0
#
#        gender  registered_via  registration_init_time  expiration_date
# 0         NaN               7                20120102         20171005
# 1      female               9                20110525         20170911
# 2      female               9                20110525         20170911
# 3      female               9                20110525         20170911
# 4         NaN               7                20120102         20171005
# ...       ...             ...                     ...              ...
# 99995     NaN               9                20150321         20170923
# 99996     NaN               7                20120117         20171004
# 99997     NaN               9                20110322         20180403
# 99998     NaN               7                20120117         20171004
# 99999     NaN               7                20150706         20170921
#
# [100000 rows x 20 columns]

# %%
merged_df['genre_ids'] = merged_df['genre_ids'].fillna('unknown').str.split('|').apply(lambda x: ','.join(map(str, x)))
merged_df['artist_name'] = merged_df['artist_name'].map(lambda x: x.lower() if isinstance(x, str) else 'unknown')
merged_df['composer'] = merged_df['composer'].map(lambda x: x.lower() if isinstance(x, str) else 'unknown')
merged_df['lyricist'] = merged_df['lyricist'].map(lambda x: x.lower() if isinstance(x, str) else 'unknown')
merged_df['song_length'] = merged_df['song_length'].fillna(0).astype(int)
merged_df['language'] = merged_df['language'].fillna(-1).astype(int)

# %%
for i in merged_df.select_dtypes(include=['object']).columns:
    merged_df[i][merged_df[i].isnull()] = 'unknown'
merged_df = merged_df.fillna(value=0)

# %%
merged_df.isnull().sum()
# Out:
# msno                      0
# song_id                   0
# source_system_tab         0
# source_screen_name        0
# source_type               0
# target                    0
# song_length               0
# genre_ids                 0
# artist_name               0
# composer                  0
# lyricist                  0
# language                  0
# name                      0
# isrc                      0
# city                      0
# bd                        0
# gender                    0
# registered_via            0
# registration_init_time    0
# expiration_date           0
# dtype: int64

# %%
#profile = ProfileReport(merged_df, title="Cars Listing Report")
#profile

# %%
merged_df['registration_init_time'] = pd.to_datetime(merged_df['registration_init_time'])
merged_df['registration_init_timeByMonth'] = merged_df['registration_init_time'].dt.month
merged_df['registration_init_timeByYear'] = merged_df['registration_init_time'].dt.year

merged_df['expiration_date'] = pd.to_datetime(merged_df['expiration_date'])
merged_df['expiration_dateByMonth'] = merged_df['expiration_date'].dt.month
merged_df['expiration_dateByYear'] = merged_df['expiration_date'].dt.year

# %% [markdown]
# # Encoding

# %%
merged_df.dropna(axis=0, subset=['target'], inplace=True)
y = merged_df['target']
X = merged_df.drop(['target','registration_init_time','expiration_date'],axis=1)

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state=4)

for colname in X.select_dtypes("object"):
    X_train[colname], _ = X_train[colname].factorize()
    X_valid[colname], _ = X_valid[colname].factorize()

# %%
corr_matrix = merged_df.corr()
corr_values = corr_matrix['target']
print(corr_values)
# Out:
# target                           1.000000
# song_length                     -0.000529
# language                        -0.015208
# city                             0.010351
# bd                              -0.008666
# registered_via                  -0.007355
# registration_init_timeByMonth         NaN
# registration_init_timeByYear          NaN
# expiration_dateByMonth                NaN
# expiration_dateByYear                 NaN
# Name: target, dtype: float64

# %%
merged_df
# Out:
#                                                msno  \
# 0      FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1      Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2      Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3      Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4      FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# ...                                             ...
# 99995  EedNarOVNUU5ppYW/ho+KV8V29zuf7m3+Df5qnQ9FT4=
# 99996  xyxz9lf8ipoxELeDLlazmHVZHE1ZYqE6iwfJWkH3Ojc=
# 99997  vDi/nHqBu7wb+DtI2Ix4TupWQatUEFR41mDC0c8Voh8=
# 99998  xyxz9lf8ipoxELeDLlazmHVZHE1ZYqE6iwfJWkH3Ojc=
# 99999  n8TgRhOBw+DthR6N6ie/63yp3KHA20UVHlbK9nY9nIc=
#
#                                             song_id source_system_tab  \
# 0      BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1      bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2      JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3      2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4      3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# ...                                             ...               ...
# 99995  c7bvJHblBfQGFJG+DcltwclubmlYvIRTT964Lu4WWXI=        my library
# 99996  MZTwICqr12ijCeBaWeKVJZ67Bz7NI0WA4bqB1IwR4jI=        my library
# 99997  xK0clTH8TvjG6sKmJXZuMLzhikhlEsolLtx2AHBpmbQ=        my library
# 99998  SoPkcfpiBjDpZSNPN3HdbPI8WAkuenayPXyBRK91T2s=        my library
# 99999  PEEg0ODi9cPg1VXM9EOhZtV39sBJFr/9cIflhbHJ5Bs=        my library
#
#         source_screen_name      source_type  target  song_length genre_ids  \
# 0                  Explore  online-playlist       1       206471       359
# 1      Local playlist more   local-playlist       1       284584      1259
# 2      Local playlist more   local-playlist       1       225396      1259
# 3      Local playlist more   local-playlist       1       255512      1019
# 4                  Explore  online-playlist       1       187802      1011
# ...                    ...              ...     ...          ...       ...
# 99995  Local playlist more   local-playlist       1       236982       465
# 99996  Local playlist more    local-library       0       228241       465
# 99997  Local playlist more    local-library       1       196812       465
# 99998  Local playlist more    local-library       0       215775       465
# 99999  Local playlist more    local-library       1       191425       465
#
#              artist_name                                           composer  \
# 0               bastille                               dan smith| mark crew
# 1        various artists                                            unknown
# 2                    nas               n. jones、w. adams、j. lordan、d. ingle
# 3               soundway                                      kwadwo donkoh
# 4            brett young            brett young| kelly archer| justin ebach
# ...                  ...                                                ...
# 99995               2ne1                                            unknown
# 99996      one direction  wayne hector| john ryan| julian bunetta| ed dr...
# 99997  michael giacchino       mikkel eriksen|sia furler|tor erik hermansen
# 99998         katy perry  katy perry| max martin| jordan houston| lukasz...
# 99999      孫盛希 (shi shi)                                                孫盛希
#
#        ... city  bd   gender registered_via        registration_init_time  \
# 0      ...    1   0  unknown              7 1970-01-01 00:00:00.020120102
# 1      ...   13  24   female              9 1970-01-01 00:00:00.020110525
# 2      ...   13  24   female              9 1970-01-01 00:00:00.020110525
# 3      ...   13  24   female              9 1970-01-01 00:00:00.020110525
# 4      ...    1   0  unknown              7 1970-01-01 00:00:00.020120102
# ...    ...  ...  ..      ...            ...                           ...
# 99995  ...   14   0  unknown              9 1970-01-01 00:00:00.020150321
# 99996  ...    1   0  unknown              7 1970-01-01 00:00:00.020120117
# 99997  ...   13   0  unknown              9 1970-01-01 00:00:00.020110322
# 99998  ...    1   0  unknown              7 1970-01-01 00:00:00.020120117
# 99999  ...    1   0  unknown              7 1970-01-01 00:00:00.020150706
#
#                     expiration_date registration_init_timeByMonth  \
# 0     1970-01-01 00:00:00.020171005                             1
# 1     1970-01-01 00:00:00.020170911                             1
# 2     1970-01-01 00:00:00.020170911                             1
# 3     1970-01-01 00:00:00.020170911                             1
# 4     1970-01-01 00:00:00.020171005                             1
# ...                             ...                           ...
# 99995 1970-01-01 00:00:00.020170923                             1
# 99996 1970-01-01 00:00:00.020171004                             1
# 99997 1970-01-01 00:00:00.020180403                             1
# 99998 1970-01-01 00:00:00.020171004                             1
# 99999 1970-01-01 00:00:00.020170921                             1
#
#        registration_init_timeByYear expiration_dateByMonth  \
# 0                              1970                      1
# 1                              1970                      1
# 2                              1970                      1
# 3                              1970                      1
# 4                              1970                      1
# ...                             ...                    ...
# 99995                          1970                      1
# 99996                          1970                      1
# 99997                          1970                      1
# 99998                          1970                      1
# 99999                          1970                      1
#
#       expiration_dateByYear
# 0                      1970
# 1                      1970
# 2                      1970
# 3                      1970
# 4                      1970
# ...                     ...
# 99995                  1970
# 99996                  1970
# 99997                  1970
# 99998                  1970
# 99999                  1970
#
# [100000 rows x 24 columns]

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# # Modeling

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# create SVM classifier object
svm_classifier = SVC(kernel='linear')

# fit the model on training data
svm_classifier.fit(X_train, y_train)

# predict on validation data
y_pred = svm_classifier.predict(X_valid)

# calculate classification report
report = classification_report(y_valid, y_pred)

# print the report
print(report)
